# %%
# %matplotlib inline
import numpy as np
from scipy.special import erf
from scipy.optimize import fixed_point
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5, 5, 100)
def m(x, h=0.5, J=1, sigma=1): 
    return 0.5*(1+erf((J*x-h)/np.sqrt(2*sigma**2)))
# plt.plot(x,y)
# for h in np.linspace(-5, 5, 100):
#     plt.plot(x, fixed_point(m, x, args=(h, 5, 1)))

for h in np.linspace(-1, 1, 3):
    plt.plot(x, erf(0.5*x-h))
plt.plot(x, x)

# %%
plt.plot(x, 0.5*(1+np.tanh(x)))
