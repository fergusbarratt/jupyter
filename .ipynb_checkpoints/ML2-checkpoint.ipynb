# %%
# %matplotlib inline
import matplotlib as mpl
# mpl.rcParams['figure.figsize'] = 200, 10
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbs
import json
sbs.set()

# %%
path1 = '/Users/fergusbarratt/Downloads/usagov_bitly_data2013-05-17-1368832207'
path2 = '/Users/fergusbarratt/Downloads/usagov_bitly_data2013-05-17-1368825005'
records = [json.loads(line) for line in open(path1) if 'll' in json.loads(line)] + [json.loads(line) for line in open(path2) if 'll' in json.loads(line)]
record_data = pd.Series([record['ll'] for record in records])

# %%
dat = record_data.as_matrix()

# %%
plt.scatter(np.array(list(dat[:]), dtype=np.float)[:, 1], np.array(list(dat[:]), dtype=np.float)[:, 0])
